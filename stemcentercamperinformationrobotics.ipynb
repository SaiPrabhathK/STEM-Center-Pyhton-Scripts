# %%
pip install xlrd

# %%
import pandas as pd

org_data = pd.read_excel('MS&T Summer Camp Registrants 2022 Form (Responses).xlsx')

org_data

# %%
rslt_df = org_data[org_data['Summer Camp(s) Attending'] == "Robotics Camp 2022"]

# %%
rslt_df

# %%
df2 = rslt_df[["Student Last Name", "Student First Name", "Student Middle Name", "Parent/Guardian Last Name", "Parent/Guardian First Name", "I consent to the Audio/Visual Release Form", "Phone Number","1. Will your child be bringing any type of medicine to this event?", "2. Does your child have any allergies?`","If yes, explain", "3. Describe any special needs (medical, physical or mental challenges) officials should be aware of in making this program safe and accessible for your child.", "4. Does your child have any special dietary needs?", "5. Does your child have any other restrictions or needs, not described above?", "The following Over-the-Counter (OTC) medications will be available from the camp nurse or camp director/coordinator. These medications will be dispensed as labeled on the original container. Please indicate all, if any, that may be given to your child, on an as needed basis:", "Are there other authorized adults that are allowed to pick up your child or receive information, other than the person completing this form? Please list their names and contact information below. "]].copy()

# %%
df2

# %%
df2.to_excel(r'Robotics Campers.xlsx', index = False)
